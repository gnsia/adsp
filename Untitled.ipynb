# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

# %%
import numpy as np

data = np.random.randint(-100,100,50).cumsum()
data
# Out:
# array([   83,    21,   -46,     6,   -81,  -126,  -222,  -312,  -317,
#         -413,  -399,  -446,  -485,  -577,  -558,  -497,  -484,  -537,
#         -552,  -453,  -534,  -613,  -626,  -698,  -704,  -714,  -788,
#         -734,  -796,  -810,  -816,  -797,  -875,  -875,  -854,  -906,
#         -987,  -936,  -906,  -994, -1056,  -996,  -969,  -986,  -971,
#         -873,  -821,  -823,  -745,  -731])

# %%
plt.plot(range(50), data)
plt.title('시간별 가격 추이')
plt.ylabel('주식가격')
plt.xlabel('시간')
plt.show()
